# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
os.chdir('./data/')

# %%
img = cv2.imread('logo.png')
img = cv2.resize(img, (512,512))

# convert img to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# detect edges in the image
_,thresh = cv2.threshold(gray, 0, 255, 0) # img, threshold value, max value, type of threshold "0 means binary"
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

print(len(contours))
# draw contours on the image
cv2.drawContours(img, contours, -1, (0,255,0), 3) # img, contours, contour index "-1 mean all contours", color (b,g,r), thickness

cv2.imshow('img', img)
cv2.imshow('gray', gray)
cv2.imshow('thresh', thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 12
# QSocketNotifier: Can only be used with threads started with QThread
