# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import spacy
from google.colab import drive

drive.mount('/content/drive')
warnings.filterwarnings('ignore')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Notebooks/bbc-text.csv')
df.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
df['category'].value_counts()
# Out:
# category
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: count, dtype: int64

# %%
import re

nlp = spacy.load('en_core_web_sm')


def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    doc = nlp(text)

    cleaned_text = [
        token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    res = " ".join(cleaned_text)
    return res

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
df.head()
# Out:
#         category                                               text  \
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...
#
#                                           clean_text
# 0  tv future hand viewer home theatre system plas...
# 1  worldcom boss leave book worldcom boss bernie ...
# 2  tiger wary farrell gamble leicester rush make ...
# 3  yeade face newcastle fa cup premiership newcas...
# 4  ocean s raid box office ocean s crime caper se...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df['clean_text'], df['category'], test_size=0.2, random_state=42)

# %% [markdown]
# i will use Embedding for training <br>
# so i should convert every text to vector of numbers every number will refer to a word i will use <b>Tokenizer<b>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

oov_tok = "<OOV>"  # if the word is not exist give it 1
vocab_size = 10000
# give an index for every word
tokanizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokanizer.fit_on_texts(X_train)
word_idx = tokanizer.word_index

# %%
word_idx
# Out:
# {'<OOV>': 1,
#  's': 2,
#  'say': 3,
#  'mr': 4,
#  'year': 5,
#  'm': 6,
#  'new': 7,
#  'people': 8,
#  'good': 9,
#  'win': 10,
#  'game': 11,
#  'time': 12,
#  't': 13,
#  'come': 14,
#  'world': 15,
#  'play': 16,
#  'government': 17,
#  'company': 18,
#  'film': 19,
#  'go': 20,
#  'tell': 21,
#  'uk': 22,
#  'work': 23,
#  'take': 24,
#  'firm': 25,
#  'think': 26,
#  'want': 27,
#  'add': 28,
#  'include': 29,
#  'music': 30,
#  'service': 31,
#  'like': 32,
#  '000': 33,
#  'month': 34,
#  'plan': 35,
#  'number': 36,
#  'set': 37,
#  'market': 38,
#  'way': 39,
#  'player': 40,
#  'week': 41,
#  'country': 42,
#  'report': 43,
#  'need': 44,
#  'party': 45,
#  'labour': 46,
#  'bbc': 47,
#  'look': 48,
#  'home': 49,
#  'big': 50,
#  'sale': 51,
#  'minister': 52,
#  'day': 53,
#  'help': 54,
#  'million': 55,
#  'election': 56,
#  'technology': 57,
#  'expect': 58,
#  'rise': 59,
#  'use': 60,
#  'second': 61,
#  'find': 62,
#  'right': 63,
#  'get': 64,
#  'mobile': 65,
#  '2004': 66,
#  'england': 67,
#  'know': 68,
#  'start': 69,
#  'group': 70,
#  'award': 71,
#  'give': 72,
#  'see': 73,
#  'high': 74,
#  'offer': 75,
#  'early': 76,
#  'claim': 77,
#  'share': 78,
#  'lead': 79,
#  'phone': 80,
#  'public': 81,
#  'try': 82,
#  'end': 83,
#  'blair': 84,
#  'system': 85,
#  'hold': 86,
#  'record': 87,
#  'show': 88,
#  'run': 89,
#  'star': 90,
#  'price': 91,
#  'call': 92,
#  'deal': 93,
#  'british': 94,
#  'tory': 95,
#  'change': 96,
#  'issue': 97,
#  'follow': 98,
#  'great': 99,
#  'european': 100,
#  'news': 101,
#  'believe': 102,
#  'tv': 103,
#  'face': 104,
#  'place': 105,
#  '10': 106,
#  'hope': 107,
#  'lose': 108,
#  'economy': 109,
#  'cost': 110,
#  'law': 111,
#  'bank': 112,
#  'brown': 113,
#  'increase': 114,
#  'chief': 115,
#  'pay': 116,
#  'fall': 117,
#  'hit': 118,
#  'cut': 119,
#  'user': 120,
#  'open': 121,
#  'growth': 122,
#  'mean': 123,
#  'business': 124,
#  'director': 125,
#  'man': 126,
#  'continue': 127,
#  'point': 128,
#  'net': 129,
#  'rate': 130,
#  'team': 131,
#  'problem': 132,
#  'international': 133,
#  'release': 134,
#  'britain': 135,
#  '2005': 136,
#  'don': 137,
#  'well': 138,
#  'club': 139,
#  'make': 140,
#  'late': 141,
#  'sell': 142,
#  'figure': 143,
#  'accord': 144,
#  'industry': 145,
#  'economic': 146,
#  'london': 147,
#  'decision': 148,
#  'analyst': 149,
#  'leave': 150,
#  'money': 151,
#  'computer': 152,
#  'digital': 153,
#  'thing': 154,
#  'rule': 155,
#  'network': 156,
#  'allow': 157,
#  'long': 158,
#  'life': 159,
#  'return': 160,
#  'consumer': 161,
#  'court': 162,
#  'lord': 163,
#  'buy': 164,
#  'tax': 165,
#  'job': 166,
#  'case': 167,
#  'software': 168,
#  'howard': 169,
#  'result': 170,
#  'support': 171,
#  'final': 172,
#  '2003': 173,
#  'executive': 174,
#  'campaign': 175,
#  'action': 176,
#  'europe': 177,
#  'leader': 178,
#  'security': 179,
#  'remain': 180,
#  'match': 181,
#  'office': 182,
#  'future': 183,
#  'attack': 184,
#  'child': 185,
#  'interest': 186,
#  'ask': 187,
#  'control': 188,
#  'website': 189,
#  'radio': 190,
#  'launch': 191,
#  'wale': 192,
#  'state': 193,
#  'site': 194,
#  'spokesman': 195,
#  'lot': 196,
#  'general': 197,
#  'close': 198,
#  'ireland': 199,
#  'france': 200,
#  'programme': 201,
#  'information': 202,
#  'title': 203,
#  'break': 204,
#  'charge': 205,
#  'bill': 206,
#  'power': 207,
#  'online': 208,
#  'likely': 209,
#  'despite': 210,
#  'large': 211,
#  'turn': 212,
#  'bring': 213,
#  'vote': 214,
#  'nation': 215,
#  'talk': 216,
#  'national': 217,
#  'grow': 218,
#  'spend': 219,
#  'video': 220,
#  've': 221,
#  'united': 222,
#  'meet': 223,
#  'cup': 224,
#  'o': 225,
#  'level': 226,
#  'chance': 227,
#  'president': 228,
#  'strong': 229,
#  'member': 230,
#  'song': 231,
#  'away': 232,
#  'create': 233,
#  'feel': 234,
#  'hard': 235,
#  'minute': 236,
#  'research': 237,
#  'beat': 238,
#  'low': 239,
#  'prime': 240,
#  '2': 241,
#  'announce': 242,
#  'oil': 243,
#  'send': 244,
#  'receive': 245,
#  'real': 246,
#  'china': 247,
#  'force': 248,
#  'medium': 249,
#  'able': 250,
#  'act': 251,
#  'test': 252,
#  'far': 253,
#  'michael': 254,
#  'provide': 255,
#  'later': 256,
#  'role': 257,
#  'january': 258,
#  'demand': 259,
#  'december': 260,
#  'past': 261,
#  'fail': 262,
#  'legal': 263,
#  'woman': 264,
#  'mark': 265,
#  'line': 266,
#  'house': 267,
#  'suggest': 268,
#  '20': 269,
#  'coach': 270,
#  'recent': 271,
#  'drive': 272,
#  'mp': 273,
#  'current': 274,
#  'band': 275,
#  'policy': 276,
#  'datum': 277,
#  'microsoft': 278,
#  'access': 279,
#  'foreign': 280,
#  'list': 281,
#  'sign': 282,
#  'financial': 283,
#  'reach': 284,
#  'trade': 285,
#  'concern': 286,
#  'statement': 287,
#  'season': 288,
#  'book': 289,
#  'internet': 290,
#  'warn': 291,
#  'let': 292,
#  'secretary': 293,
#  'major': 294,
#  'john': 295,
#  'card': 296,
#  'official': 297,
#  'half': 298,
#  'happen': 299,
#  'order': 300,
#  '1': 301,
#  'injury': 302,
#  'clear': 303,
#  'single': 304,
#  'council': 305,
#  'young': 306,
#  'device': 307,
#  'd': 308,
#  'target': 309,
#  '3': 310,
#  'dollar': 311,
#  'download': 312,
#  'search': 313,
#  'sport': 314,
#  'head': 315,
#  'david': 316,
#  'key': 317,
#  'ahead': 318,
#  'budget': 319,
#  'raise': 320,
#  'email': 321,
#  'performance': 322,
#  'centre': 323,
#  'important': 324,
#  'miss': 325,
#  'chancellor': 326,
#  'pc': 327,
#  'file': 328,
#  'ms': 329,
#  'message': 330,
#  'live': 331,
#  '12': 332,
#  'south': 333,
#  'profit': 334,
#  'agree': 335,
#  'personal': 336,
#  'different': 337,
#  'event': 338,
#  'write': 339,
#  'hand': 340,
#  'currently': 341,
#  'question': 342,
#  'movie': 343,
#  'bid': 344,
#  'fund': 345,
#  'sunday': 346,
#  'project': 347,
#  'police': 348,
#  'product': 349,
#  'area': 350,
#  'manager': 351,
#  'form': 352,
#  'investment': 353,
#  'eu': 354,
#  'school': 355,
#  'local': 356,
#  'fan': 357,
#  'union': 358,
#  'scotland': 359,
#  'free': 360,
#  'conservative': 361,
#  'appear': 362,
#  'version': 363,
#  'quarter': 364,
#  'political': 365,
#  'small': 366,
#  'develop': 367,
#  'little': 368,
#  'meeting': 369,
#  'begin': 370,
#  'broadband': 371,
#  'march': 372,
#  '100': 373,
#  'series': 374,
#  'term': 375,
#  'japan': 376,
#  'aim': 377,
#  'standard': 378,
#  'ago': 379,
#  'family': 380,
#  '50': 381,
#  'winner': 382,
#  'commission': 383,
#  'champion': 384,
#  'victory': 385,
#  'war': 386,
#  'wednesday': 387,
#  'race': 388,
#  'base': 389,
#  'february': 390,
#  'old': 391,
#  'comment': 392,
#  'move': 393,
#  'bad': 394,
#  'city': 395,
#  'decide': 396,
#  'rugby': 397,
#  'tony': 398,
#  'tuesday': 399,
#  'actor': 400,
#  'produce': 401,
#  'olympic': 402,
#  'build': 403,
#  '30': 404,
#  'american': 405,
#  'boost': 406,
#  'customer': 407,
#  '4': 408,
#  'involve': 409,
#  'euro': 410,
#  'india': 411,
#  'consider': 412,
#  'fight': 413,
#  'account': 414,
#  'car': 415,
#  'view': 416,
#  'stock': 417,
#  'today': 418,
#  'speak': 419,
#  'deny': 420,
#  'monday': 421,
#  'content': 422,
#  'challenge': 423,
#  '11': 424,
#  'production': 425,
#  'album': 426,
#  'stop': 427,
#  'ensure': 428,
#  'spending': 429,
#  'forward': 430,
#  'trial': 431,
#  '5': 432,
#  'possible': 433,
#  'goal': 434,
#  'prize': 435,
#  'league': 436,
#  'saturday': 437,
#  'feature': 438,
#  'program': 439,
#  'november': 440,
#  'seek': 441,
#  'development': 442,
#  'success': 443,
#  'williams': 444,
#  'stand': 445,
#  'drug': 446,
#  'sir': 447,
#  'chelsea': 448,
#  'age': 449,
#  'street': 450,
#  'proposal': 451,
#  'huge': 452,
#  'host': 453,
#  'join': 454,
#  'design': 455,
#  'apple': 456,
#  'global': 457,
#  'ban': 458,
#  'total': 459,
#  'link': 460,
#  'fast': 461,
#  'name': 462,
#  'appeal': 463,
#  'improve': 464,
#  'drop': 465,
#  'debt': 466,
#  'step': 467,
#  'committee': 468,
#  '25': 469,
#  'argue': 470,
#  'watch': 471,
#  'available': 472,
#  'aid': 473,
#  'main': 474,
#  'previous': 475,
#  'chart': 476,
#  'chairman': 477,
#  'friday': 478,
#  'stage': 479,
#  'accuse': 480,
#  'hour': 481,
#  'opportunity': 482,
#  'fear': 483,
#  'jones': 484,
#  'competition': 485,
#  '2001': 486,
#  'effort': 487,
#  'promise': 488,
#  'box': 489,
#  'present': 490,
#  'human': 491,
#  'focus': 492,
#  'christmas': 493,
#  'choice': 494,
#  'position': 495,
#  'boss': 496,
#  'board': 497,
#  'lib': 498,
#  'insist': 499,
#  'career': 500,
#  '15': 501,
#  'value': 502,
#  'easy': 503,
#  'poor': 504,
#  'web': 505,
#  'prove': 506,
#  'black': 507,
#  'italy': 508,
#  'oscar': 509,
#  'dem': 510,
#  'screen': 511,
#  'giant': 512,
#  'carry': 513,
#  'football': 514,
#  'parliament': 515,
#  'pressure': 516,
#  'predict': 517,
#  'camera': 518,
#  'score': 519,
#  'agency': 520,
#  'idea': 521,
#  'cash': 522,
#  'image': 523,
#  'limit': 524,
#  'picture': 525,
#  'speed': 526,
#  'community': 527,
#  'thursday': 528,
#  'tour': 529,
#  'fact': 530,
#  'york': 531,
#  'admit': 532,
#  'cause': 533,
#  'rival': 534,
#  'september': 535,
#  'double': 536,
#  'g': 537,
#  'popular': 538,
#  'television': 539,
#  'bit': 540,
#  'sony': 541,
#  'virus': 542,
#  'liberal': 543,
#  'recently': 544,
#  'pick': 545,
#  'gadget': 546,
#  'iraq': 547,
#  'authority': 548,
#  'draw': 549,
#  'reveal': 550,
#  'reduce': 551,
#  'trust': 552,
#  'difficult': 553,
#  'instead': 554,
#  'fourth': 555,
#  'love': 556,
#  'benefit': 557,
#  'risk': 558,
#  'attempt': 559,
#  'push': 560,
#  'battle': 561,
#  'story': 562,
#  'health': 563,
#  'festival': 564,
#  'weekend': 565,
#  'department': 566,
#  'stay': 567,
#  'voter': 568,
#  'newspaper': 569,
#  'judge': 570,
#  'singer': 571,
#  'experience': 572,
#  'process': 573,
#  'confirm': 574,
#  'damage': 575,
#  'summer': 576,
#  'pass': 577,
#  'airline': 578,
#  'october': 579,
#  'similar': 580,
#  'suffer': 581,
#  'association': 582,
#  'sure': 583,
#  'slow': 584,
#  'compare': 585,
#  'didn': 586,
#  'survey': 587,
#  'sector': 588,
#  'investor': 589,
#  'paul': 590,
#  'special': 591,
#  'annual': 592,
#  'track': 593,
#  'choose': 594,
#  'direct': 595,
#  'keep': 596,
#  'evidence': 597,
#  'ball': 598,
#  'press': 599,
#  'exchange': 600,
#  'liverpool': 601,
#  'championship': 602,
#  'audience': 603,
#  'education': 604,
#  'compete': 605,
#  'common': 606,
#  'short': 607,
#  'save': 608,
#  'tough': 609,
#  'robinson': 610,
#  'producer': 611,
#  'measure': 612,
#  'machine': 613,
#  'simply': 614,
#  'moment': 615,
#  'deliver': 616,
#  'replace': 617,
#  '18': 618,
#  'immigration': 619,
#  'french': 620,
#  'individual': 621,
#  'rock': 622,
#  'russian': 623,
#  'body': 624,
#  'extra': 625,
#  'manchester': 626,
#  'potential': 627,
#  'seven': 628,
#  'conference': 629,
#  '200': 630,
#  'finish': 631,
#  'debate': 632,
#  'back': 633,
#  'gordon': 634,
#  '40': 635,
#  'reform': 636,
#  'martin': 637,
#  'contract': 638,
#  'date': 639,
#  'export': 640,
#  'senior': 641,
#  'have': 642,
#  'irish': 643,
#  'affect': 644,
#  'publish': 645,
#  'serve': 646,
#  'organisation': 647,
#  'understand': 648,
#  'africa': 649,
#  'yukos': 650,
#  'independent': 651,
#  '2002': 652,
#  'introduce': 653,
#  'estimate': 654,
#  'speech': 655,
#  'range': 656,
#  'favourite': 657,
#  'detail': 658,
#  'dvd': 659,
#  'brand': 660,
#  'university': 661,
#  'finance': 662,
#  'store': 663,
#  'gain': 664,
#  'forecast': 665,
#  'period': 666,
#  'air': 667,
#  'copy': 668,
#  'defeat': 669,
#  'fine': 670,
#  'dr': 671,
#  'round': 672,
#  'deficit': 673,
#  'ukip': 674,
#  'impact': 675,
#  'soon': 676,
#  'loss': 677,
#  'hear': 678,
#  'review': 679,
#  'protect': 680,
#  'australian': 681,
#  'revenue': 682,
#  'voice': 683,
#  'study': 684,
#  'electronic': 685,
#  'parent': 686,
#  'germany': 687,
#  'matter': 688,
#  'operation': 689,
#  'wrong': 690,
#  'squad': 691,
#  'category': 692,
#  'model': 693,
#  'poll': 694,
#  'grand': 695,
#  'accept': 696,
#  'night': 697,
#  'die': 698,
#  'entertainment': 699,
#  'care': 700,
#  'charles': 701,
#  'scheme': 702,
#  'situation': 703,
#  'v': 704,
#  'avoid': 705,
#  'credit': 706,
#  'history': 707,
#  '2000': 708,
#  'penalty': 709,
#  'actress': 710,
#  'taxis': 711,
#  'happy': 712,
#  'reason': 713,
#  'average': 714,
#  'original': 715,
#  'sound': 716,
#  'doubt': 717,
#  'console': 718,
#  'll': 719,
#  'maker': 720,
#  '60': 721,
#  'private': 722,
#  'shareholder': 723,
#  'course': 724,
#  'comedy': 725,
#  'describe': 726,
#  'operator': 727,
#  'post': 728,
#  'artist': 729,
#  '2006': 730,
#  'reject': 731,
#  'blog': 732,
#  'effect': 733,
#  '24': 734,
#  'bush': 735,
#  'approach': 736,
#  'unit': 737,
#  'nomination': 738,
#  'smith': 739,
#  'travel': 740,
#  'roddick': 741,
#  'energy': 742,
#  'economist': 743,
#  'google': 744,
#  'wait': 745,
#  'disaster': 746,
#  'australia': 747,
#  'gaming': 748,
#  'scottish': 749,
#  '17': 750,
#  'criminal': 751,
#  'perform': 752,
#  'mike': 753,
#  '13': 754,
#  'agreement': 755,
#  'america': 756,
#  'arsenal': 757,
#  'fuel': 758,
#  'wide': 759,
#  'fit': 760,
#  '500': 761,
#  'represent': 762,
#  'ceremony': 763,
#  'kennedy': 764,
#  'threat': 765,
#  'pop': 766,
#  'tackle': 767,
#  'answer': 768,
#  'studio': 769,
#  'word': 770,
#  'central': 771,
#  'fraud': 772,
#  'lawyer': 773,
#  'russia': 774,
#  'west': 775,
#  'alan': 776,
#  'refuse': 777,
#  '16': 778,
#  'generation': 779,
#  'captain': 780,
#  'german': 781,
#  'source': 782,
#  'station': 783,
#  'manage': 784,
#  'death': 785,
#  'response': 786,
#  'previously': 787,
#  'critic': 788,
#  'hollywood': 789,
#  'friend': 790,
#  'struggle': 791,
#  'expert': 792,
#  'cover': 793,
#  '14': 794,
#  'particularly': 795,
#  'indian': 796,
#  'example': 797,
#  'widely': 798,
#  'paper': 799,
#  'campbell': 800,
#  'april': 801,
#  'blunkett': 802,
#  'channel': 803,
#  'connection': 804,
#  'davis': 805,
#  'handset': 806,
#  'james': 807,
#  'address': 808,
#  'johnson': 809,
#  'billion': 810,
#  'quality': 811,
#  'secure': 812,
#  'student': 813,
#  'debut': 814,
#  'couple': 815,
#  'civil': 816,
#  'row': 817,
#  'andy': 818,
#  'kilroysilk': 819,
#  'outside': 820,
#  'exist': 821,
#  'visit': 822,
#  'crime': 823,
#  'defend': 824,
#  'income': 825,
#  'light': 826,
#  'jump': 827,
#  'complete': 828,
#  'robert': 829,
#  'richard': 830,
#  'heart': 831,
#  'gold': 832,
#  'unveil': 833,
#  'positive': 834,
#  'nearly': 835,
#  'criticise': 836,
#  'earn': 837,
#  'management': 838,
#  'honour': 839,
#  'majority': 840,
#  'spot': 841,
#  'bt': 842,
#  'june': 843,
#  'enjoy': 844,
#  'rest': 845,
#  'achieve': 846,
#  '6': 847,
#  'confidence': 848,
#  'field': 849,
#  'defence': 850,
#  'athens': 851,
#  'read': 852,
#  'domestic': 853,
#  'display': 854,
#  'sort': 855,
#  'pension': 856,
#  'pledge': 857,
#  'fox': 858,
#  'premiership': 859,
#  'white': 860,
#  'asylum': 861,
#  'opening': 862,
#  'worth': 863,
#  'east': 864,
#  'theatre': 865,
#  'strike': 866,
#  'road': 867,
#  'property': 868,
#  'worker': 869,
#  'enter': 870,
#  'staff': 871,
#  'stake': 872,
#  'decline': 873,
#  'protection': 874,
#  'ground': 875,
#  'spain': 876,
#  'society': 877,
#  'pair': 878,
#  'newcastle': 879,
#  'officer': 880,
#  'chip': 881,
#  'arrest': 882,
#  'thousand': 883,
#  'blue': 884,
#  'training': 885,
#  'indoor': 886,
#  'spam': 887,
#  'explain': 888,
#  'park': 889,
#  'recovery': 890,
#  'hunt': 891,
#  'zealand': 892,
#  'clarke': 893,
#  'owner': 894,
#  'tsunami': 895,
#  'shoot': 896,
#  'de': 897,
#  'supporter': 898,
#  'patent': 899,
#  'encourage': 900,
#  'thomas': 901,
#  'kelly': 902,
#  'significant': 903,
#  'chinese': 904,
#  'probably': 905,
#  'politician': 906,
#  'near': 907,
#  'madrid': 908,
#  'decade': 909,
#  'keen': 910,
#  'fair': 911,
#  'ipod': 912,
#  'propose': 913,
#  'text': 914,
#  'confident': 915,
#  'code': 916,
#  'broadcast': 917,
#  'put': 918,
#  'japanese': 919,
#  'cross': 920,
#  'north': 921,
#  'victim': 922,
#  'inquiry': 923,
#  'wireless': 924,
#  'ability': 925,
#  'highdefinition': 926,
#  'urge': 927,
#  'social': 928,
#  'kind': 929,
#  'cabinet': 930,
#  'supply': 931,
#  'illegal': 932,
#  'kick': 933,
#  'require': 934,
#  'politic': 935,
#  'english': 936,
#  'musical': 937,
#  'investigation': 938,
#  'asia': 939,
#  'interview': 940,
#  'land': 941,
#  'material': 942,
#  'sentence': 943,
#  'announcement': 944,
#  'certainly': 945,
#  'prevent': 946,
#  'shadow': 947,
#  'subject': 948,
#  'own': 949,
#  'especially': 950,
#  'advantage': 951,
#  'separate': 952,
#  'federal': 953,
#  'controversial': 954,
#  'particular': 955,
#  'operate': 956,
#  'deutsche': 957,
#  'ferguson': 958,
#  'suspend': 959,
#  'ready': 960,
#  'progress': 961,
#  '21': 962,
#  'peter': 963,
#  'discuss': 964,
#  'recognise': 965,
#  'speculation': 966,
#  'dominate': 967,
#  'emerge': 968,
#  'lack': 969,
#  'format': 970,
#  'label': 971,
#  'thank': 972,
#  'guilty': 973,
#  'express': 974,
#  'commit': 975,
#  'xbox': 976,
#  'capacity': 977,
#  'athlete': 978,
#  'tournament': 979,
#  'learn': 980,
#  'red': 981,
#  'cheap': 982,
#  'reflect': 983,
#  'overall': 984,
#  'doesn': 985,
#  'actually': 986,
#  'tool': 987,
#  '22': 988,
#  'portable': 989,
#  'capital': 990,
#  'august': 991,
#  'takeover': 992,
#  'golden': 993,
#  'character': 994,
#  'window': 995,
#  'corporate': 996,
#  '800': 997,
#  'welcome': 998,
#  'option': 999,
#  'worry': 1000,
#  ...}

# %%
# convert the text to a vector of numbers the numbers is the word index
X_train_tokanized = tokanizer.texts_to_sequences(X_train)
X_test_tokanized = tokanizer.texts_to_sequences(X_test)

# %%
X_train_tokanized[0]
# Out:
# [3272,
#  103,
#  814,
#  400,
#  2890,
#  3272,
#  814,
#  539,
#  1797,
#  6816,
#  6817,
#  144,
#  789,
#  569,
#  1107,
#  1634,
#  19,
#  90,
#  544,
#  16,
#  203,
#  257,
#  2998,
#  2999,
#  2518,
#  7716,
#  1189,
#  1,
#  6818,
#  1290,
#  438,
#  3586,
#  511,
#  469,
#  258,
#  3272,
#  2,
#  1189,
#  3,
#  170,
#  1,
#  6819,
#  6820,
#  90,
#  201,
#  400,
#  2,
#  1189,
#  366,
#  511,
#  362,
#  47,
#  374,
#  1,
#  1399,
#  8960,
#  346,
#  697,
#  1008,
#  14,
#  83,
#  486,
#  789,
#  2,
#  1,
#  90,
#  2891,
#  257,
#  294,
#  436,
#  19,
#  2297,
#  43,
#  80,
#  1,
#  7717,
#  3272,
#  8961,
#  16,
#  257,
#  1,
#  19,
#  363,
#  6821,
#  348,
#  1008,
#  5559,
#  1463,
#  6817,
#  362,
#  3950,
#  156,
#  88,
#  803,
#  408,
#  94,
#  539,
#  1,
#  725,
#  70,
#  1125,
#  1705,
#  19,
#  90,
#  362,
#  6817,
#  29,
#  6822,
#  1876,
#  790,
#  400,
#  2231,
#  4169,
#  1,
#  595,
#  1290,
#  79,
#  90,
#  6819,
#  6820,
#  544,
#  73,
#  50,
#  511,
#  4438,
#  193,
#  595]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 200
# padding every record into specific lenght 200 (max_length)
X_train_padded = pad_sequences(X_train_tokanized, maxlen=max_len)
X_test_padded = pad_sequences(X_test_tokanized, maxlen=max_len)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation, Embedding, Bidirectional, SimpleRNN
import tensorflow as tf

model = Sequential([
    # num.of unique words in dataset, embedding_dim, len of data -> make every word will have 64 feature
    Embedding(input_dim=vocab_size, output_dim=64,
              input_length=len(X_train_padded)),
    Dropout(0.2),

    SimpleRNN(64, return_sequences=True),
    Dropout(0.2),

    SimpleRNN(64),
    Dropout(0.2),

    Dense(64, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
])

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])
# sparse_categorical_crossentropy best for lable encoder
# categorical_crossentropy best for one hot encoder

# %%
model.fit(X_train_padded, y_train_encoded, epochs=20,
          validation_data=(X_test_padded, y_test_encoded))
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 128ms/step - accuracy: 0.2279 - loss: 1.6302 - val_accuracy: 0.2472 - val_loss: 1.5910
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.3511 - loss: 1.4570 - val_accuracy: 0.4090 - val_loss: 1.2681
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.5729 - loss: 1.0623 - val_accuracy: 0.4921 - val_loss: 1.2070
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8530 - loss: 0.4900 - val_accuracy: 0.5685 - val_loss: 1.2685
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.9718 - loss: 0.1365 - val_accuracy: 0.6045 - val_loss: 1.2752
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - accuracy: 0.9921 - loss: 0.0512 - val_accuracy: 0.6067 - val_loss: 1.3300
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9929 - loss: 0.0357 - val_accuracy: 0.6090 - val_loss: 1.3999
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.9992 - loss: 0.0135 - val_accuracy: 0.5775 - val_loss: 1.6700
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.6090 - val_loss: 1.5671
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.6135 - val_loss: 1.6033
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6112 - val_loss: 1.5986
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 139ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6292 - val_loss: 1.6265
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6135 - val_loss: 1.7336
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6112 - val_loss: 1.7969
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6157 - val_loss: 1.8309
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6045 - val_loss: 1.8699
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6112 - val_loss: 1.8559
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6000 - val_loss: 2.1146
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6067 - val_loss: 2.0062
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6315 - val_loss: 1.9187
