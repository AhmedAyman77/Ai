# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras

from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.metrics import Recall, Precision
from sklearn.metrics import classification_report, confusion_matrix
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from google.colab import drive
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
# Out:
# Mounted at /content/drive

# %%
IMG_SIZE = 224
BATCH_SIZE = 64

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory='/content/drive/MyDrive/stroke_classification/Train',
    validation_split=0.2,
    subset='training',
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)
validation_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory='/content/drive/MyDrive/stroke_classification/Train',
    validation_split=0.2,
    subset='validation',
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory='/content/drive/MyDrive/stroke_classification/Test',
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 2376 files belonging to 2 classes.
# Using 1901 files for training.
# Found 2376 files belonging to 2 classes.
# Using 475 files for validation.
# Found 250 files belonging to 2 classes.

# %%
y_true = np.concatenate([y for x, y in test_data], axis=0)
y_true[0]
# Out:
# 0

# %%
IMG_IND=224
IMG_SHAPE = (IMG_IND,IMG_IND,3) # transfer learning accept only 3 channel
LOSS = BinaryCrossentropy()
SEED = 7

# %%
def callbacks(model_name):
  CallBacks = []

  best_model = ModelCheckpoint(filepath=f'{model_name}.keras',monitor='val_loss',verbose=1,save_best_only=True)
  CallBacks.append(best_model)

  early_stop = EarlyStopping(monitor='val_loss',patience=5,verbose=1)
  CallBacks.append(early_stop)

  reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,min_lr=0.00001)
  CallBacks.append(reduce_lr)

  return CallBacks

# %% [markdown]
# #DenseNet121

# %%
optimizer = Adam(learning_rate=0.001)

base_model = tf.keras.applications.DenseNet121(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SHAPE,
)


for layer in base_model.layers[421:]:
  layer.trainable = True

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

denseNet_model = tf.keras.Model(inputs=base_model.input, outputs=x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
denseNet_model.compile(
    optimizer=optimizer,
    loss=LOSS,
    metrics=['accuracy',Recall(),Precision()]
)

# %%
len(denseNet_model.layers)
# Out:
# 430

# %%
call_backs = callbacks('DenseNet121')
denseNet_model.fit(train_data,epochs=10,validation_data=validation_data,callbacks=call_backs)
# Out:
# Epoch 1/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.6344 - loss: 0.7703 - precision: 0.5483 - recall: 0.5341
# Epoch 1: val_loss improved from inf to 17.00776, saving model to DenseNet121.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 712s 18s/step - accuracy: 0.6369 - loss: 0.7651 - precision: 0.5515 - recall: 0.5356 - val_accuracy: 0.4274 - val_loss: 17.0078 - val_precision: 0.4274 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.8345 - loss: 0.3762 - precision: 0.7959 - recall: 0.7881
# Epoch 2: val_loss improved from 17.00776 to 2.87454, saving model to DenseNet121.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 690ms/step - accuracy: 0.8354 - loss: 0.3747 - precision: 0.7971 - recall: 0.7891 - val_accuracy: 0.5874 - val_loss: 2.8745 - val_precision: 0.5113 - val_recall: 0.7833 - learning_rate: 0.0010
# Epoch 3/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9262 - loss: 0.1867 - precision: 0.9254 - recall: 0.8842
# Epoch 3: val_loss improved from 2.87454 to 2.04397, saving model to DenseNet121.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 689ms/step - accuracy: 0.9266 - loss: 0.1859 - precision: 0.9255 - recall: 0.8850 - val_accuracy: 0.7537 - val_loss: 2.0440 - val_precision: 0.6734 - val_recall: 0.8227 - learning_rate: 0.0010
# Epoch 4/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.9252 - loss: 0.1889 - precision: 0.9109 - recall: 0.8936
# Epoch 4: val_loss did not improve from 2.04397
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 657ms/step - accuracy: 0.9254 - loss: 0.1885 - precision: 0.9112 - recall: 0.8938 - val_accuracy: 0.6358 - val_loss: 14.9500 - val_precision: 1.0000 - val_recall: 0.1478 - learning_rate: 0.0010
# Epoch 5/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.9726 - loss: 0.0698 - precision: 0.9605 - recall: 0.9699
# Epoch 5: val_loss did not improve from 2.04397
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 671ms/step - accuracy: 0.9728 - loss: 0.0695 - precision: 0.9609 - recall: 0.9701 - val_accuracy: 0.7874 - val_loss: 2.7533 - val_precision: 0.8446 - val_recall: 0.6158 - learning_rate: 0.0010
# Epoch 6/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9897 - loss: 0.0326 - precision: 0.9857 - recall: 0.9884
# Epoch 6: val_loss improved from 2.04397 to 0.86920, saving model to DenseNet121.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 702ms/step - accuracy: 0.9896 - loss: 0.0327 - precision: 0.9856 - recall: 0.9883 - val_accuracy: 0.8842 - val_loss: 0.8692 - val_precision: 0.9353 - val_recall: 0.7833 - learning_rate: 0.0010
# Epoch 7/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.9889 - loss: 0.0341 - precision: 0.9922 - recall: 0.9789
# Epoch 7: val_loss did not improve from 0.86920
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 656ms/step - accuracy: 0.9890 - loss: 0.0340 - precision: 0.9922 - recall: 0.9790 - val_accuracy: 0.8484 - val_loss: 1.4493 - val_precision: 0.7549 - val_recall: 0.9557 - learning_rate: 0.0010
# Epoch 8/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9829 - loss: 0.0583 - precision: 0.9786 - recall: 0.9780
# Epoch 8: val_loss improved from 0.86920 to 0.75187, saving model to DenseNet121.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 701ms/step - accuracy: 0.9830 - loss: 0.0581 - precision: 0.9787 - recall: 0.9781 - val_accuracy: 0.9116 - val_loss: 0.7519 - val_precision: 0.8852 - val_recall: 0.9113 - learning_rate: 0.0010
# Epoch 9/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.9897 - loss: 0.0331 - precision: 0.9853 - recall: 0.9890
# Epoch 9: val_loss improved from 0.75187 to 0.29084, saving model to DenseNet121.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 729ms/step - accuracy: 0.9896 - loss: 0.0334 - precision: 0.9851 - recall: 0.9888 - val_accuracy: 0.9221 - val_loss: 0.2908 - val_precision: 0.8705 - val_recall: 0.9606 - learning_rate: 0.0010
# Epoch 10/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.9815 - loss: 0.0492 - precision: 0.9787 - recall: 0.9743
# Epoch 10: val_loss did not improve from 0.29084
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 674ms/step - accuracy: 0.9814 - loss: 0.0494 - precision: 0.9787 - recall: 0.9741 - val_accuracy: 0.8674 - val_loss: 1.3299 - val_precision: 0.9730 - val_recall: 0.7094 - learning_rate: 0.0010

# %%
best_denseNet = tf.keras.models.load_model('DenseNet121.keras')
best_denseNet.evaluate(test_data,verbose=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 25s 5s/step - accuracy: 0.9090 - loss: 0.4712 - precision: 0.5284 - recall: 0.7840
# [0.48897889256477356,
#  0.9039999842643738,
#  0.9599999785423279,
#  0.8633093237876892]

# %%
y_pred = best_denseNet.predict(test_data)
y_pred = np.round(y_pred)
print(classification_report(y_true,y_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       125
#            1       0.86      0.96      0.91       125
#
#     accuracy                           0.90       250
#    macro avg       0.91      0.90      0.90       250
# weighted avg       0.91      0.90      0.90       250

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## RESNet 50

# %%
base_model = tf.keras.applications.ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SHAPE,
)

for layer in base_model.layers[420:]:
  layer.trainable = True

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

RESNet_model = tf.keras.Model(inputs=base_model.input, outputs=x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
optimizer = Adam(learning_rate=0.001)

RESNet_model.compile(
    optimizer=optimizer,
    loss=LOSS,
    metrics=['accuracy',Recall(),Precision()]
)

# %%
call_backs = callbacks('ResNet50')
RESNet_model.fit(train_data,epochs=15,validation_data=validation_data,callbacks=call_backs)
# Out:
# Epoch 1/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6292 - loss: 0.7871 - precision_1: 0.5058 - recall_1: 0.4802
# Epoch 1: val_loss improved from inf to 319.71033, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.6319 - loss: 0.7820 - precision_1: 0.5101 - recall_1: 0.4849 - val_accuracy: 0.4274 - val_loss: 319.7103 - val_precision_1: 0.4274 - val_recall_1: 1.0000 - learning_rate: 0.0010
# Epoch 2/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.8424 - loss: 0.3742 - precision_1: 0.8250 - recall_1: 0.7716
# Epoch 2: val_loss improved from 319.71033 to 3.63175, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 58s 827ms/step - accuracy: 0.8438 - loss: 0.3713 - precision_1: 0.8264 - recall_1: 0.7737 - val_accuracy: 0.8021 - val_loss: 3.6317 - val_precision_1: 0.7422 - val_recall_1: 0.8227 - learning_rate: 0.0010
# Epoch 3/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.9385 - loss: 0.1505 - precision_1: 0.9301 - recall_1: 0.9143
# Epoch 3: val_loss did not improve from 3.63175
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 35s 626ms/step - accuracy: 0.9387 - loss: 0.1503 - precision_1: 0.9301 - recall_1: 0.9148 - val_accuracy: 0.5011 - val_loss: 12.5555 - val_precision_1: 0.4595 - val_recall_1: 0.9507 - learning_rate: 0.0010
# Epoch 4/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - accuracy: 0.9638 - loss: 0.1195 - precision_1: 0.9524 - recall_1: 0.9553
# Epoch 4: val_loss improved from 3.63175 to 1.96194, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9639 - loss: 0.1189 - precision_1: 0.9525 - recall_1: 0.9553 - val_accuracy: 0.8274 - val_loss: 1.9619 - val_precision_1: 0.7553 - val_recall_1: 0.8818 - learning_rate: 0.0010
# Epoch 5/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.9834 - loss: 0.0430 - precision_1: 0.9832 - recall_1: 0.9746
# Epoch 5: val_loss improved from 1.96194 to 1.01069, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9834 - loss: 0.0430 - precision_1: 0.9831 - recall_1: 0.9748 - val_accuracy: 0.8842 - val_loss: 1.0107 - val_precision_1: 0.8491 - val_recall_1: 0.8867 - learning_rate: 0.0010
# Epoch 6/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.9838 - loss: 0.0410 - precision_1: 0.9800 - recall_1: 0.9770
# Epoch 6: val_loss did not improve from 1.01069
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 29s 624ms/step - accuracy: 0.9838 - loss: 0.0409 - precision_1: 0.9799 - recall_1: 0.9771 - val_accuracy: 0.7726 - val_loss: 2.6031 - val_precision_1: 0.6568 - val_recall_1: 0.9803 - learning_rate: 0.0010
# Epoch 7/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9860 - loss: 0.0377 - precision_1: 0.9935 - recall_1: 0.9700
# Epoch 7: val_loss did not improve from 1.01069
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 642ms/step - accuracy: 0.9861 - loss: 0.0378 - precision_1: 0.9935 - recall_1: 0.9703 - val_accuracy: 0.8884 - val_loss: 1.2622 - val_precision_1: 0.8289 - val_recall_1: 0.9310 - learning_rate: 0.0010
# Epoch 8/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9831 - loss: 0.0529 - precision_1: 0.9775 - recall_1: 0.9786
# Epoch 8: val_loss did not improve from 1.01069
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 628ms/step - accuracy: 0.9831 - loss: 0.0530 - precision_1: 0.9775 - recall_1: 0.9786 - val_accuracy: 0.5705 - val_loss: 9.8396 - val_precision_1: 0.4987 - val_recall_1: 0.9704 - learning_rate: 0.0010
# Epoch 9/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.9883 - loss: 0.0283 - precision_1: 0.9914 - recall_1: 0.9783
# Epoch 9: val_loss improved from 1.01069 to 0.14993, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9884 - loss: 0.0281 - precision_1: 0.9914 - recall_1: 0.9786 - val_accuracy: 0.9516 - val_loss: 0.1499 - val_precision_1: 0.9286 - val_recall_1: 0.9606 - learning_rate: 5.0000e-04
# Epoch 10/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9987 - loss: 0.0049 - precision_1: 1.0000 - recall_1: 0.9968
# Epoch 10: val_loss improved from 0.14993 to 0.05222, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9987 - loss: 0.0049 - precision_1: 1.0000 - recall_1: 0.9969 - val_accuracy: 0.9789 - val_loss: 0.0522 - val_precision_1: 0.9849 - val_recall_1: 0.9655 - learning_rate: 5.0000e-04
# Epoch 11/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 1.0000 - loss: 0.0015 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 11: val_loss improved from 0.05222 to 0.05087, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 1.0000 - loss: 0.0015 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.9832 - val_loss: 0.0509 - val_precision_1: 0.9803 - val_recall_1: 0.9803 - learning_rate: 5.0000e-04
# Epoch 12/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 1.0000 - loss: 6.8613e-04 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 12: val_loss improved from 0.05087 to 0.04294, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 1.0000 - loss: 6.8425e-04 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.9853 - val_loss: 0.0429 - val_precision_1: 0.9851 - val_recall_1: 0.9803 - learning_rate: 5.0000e-04
# Epoch 13/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 1.0000 - loss: 3.7167e-04 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 13: val_loss improved from 0.04294 to 0.04096, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 1.0000 - loss: 3.7162e-04 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.9874 - val_loss: 0.0410 - val_precision_1: 0.9900 - val_recall_1: 0.9803 - learning_rate: 5.0000e-04
# Epoch 14/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 1.0000 - loss: 4.4330e-04 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 14: val_loss improved from 0.04096 to 0.03884, saving model to ResNet50.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 1.0000 - loss: 4.4157e-04 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.9874 - val_loss: 0.0388 - val_precision_1: 0.9900 - val_recall_1: 0.9803 - learning_rate: 5.0000e-04
# Epoch 15/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 1.0000 - loss: 2.3143e-04 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 15: val_loss did not improve from 0.03884
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 59s 619ms/step - accuracy: 1.0000 - loss: 2.3157e-04 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.9874 - val_loss: 0.0391 - val_precision_1: 0.9900 - val_recall_1: 0.9803 - learning_rate: 5.0000e-04

# %%
best_RESNet = tf.keras.models.load_model('ResNet50.keras')
best_RESNet.evaluate(test_data,verbose=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9648 - loss: 0.1765 - precision_1: 0.6090 - recall_1: 0.7968
# [0.18447524309158325,
#  0.9639999866485596,
#  0.9919999837875366,
#  0.939393937587738]

# %%
y_pred = best_RESNet.predict(test_data)
y_pred = np.round(y_pred)
print(classification_report(y_true,y_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96       125
#            1       0.94      0.99      0.96       125
#
#     accuracy                           0.96       250
#    macro avg       0.97      0.96      0.96       250
# weighted avg       0.97      0.96      0.96       250

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ##MobileNet model

# %%
base_model = tf.keras.applications.MobileNet(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SHAPE,
)

for layer in base_model.layers[420:]:
  layer.trainable = True

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

MobileNet_model = tf.keras.Model(inputs=base_model.input, outputs=x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
optimizer = Adam(learning_rate=0.001)

MobileNet_model.compile(
    optimizer=optimizer,
    loss=LOSS,
    metrics=['accuracy',Recall(),Precision()]
)

# %%
call_backs = callbacks('MobileNet')
MobileNet_model.fit(train_data,epochs=15,validation_data=validation_data,callbacks=call_backs)
# Out:
# Epoch 1/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.6500 - loss: 0.8609 - precision_2: 0.5591 - recall_2: 0.5508
# Epoch 1: val_loss improved from inf to 3.32730, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.6527 - loss: 0.8533 - precision_2: 0.5624 - recall_2: 0.5540 - val_accuracy: 0.5726 - val_loss: 3.3273 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.8927 - loss: 0.2564 - precision_2: 0.8780 - recall_2: 0.8517
# Epoch 2: val_loss improved from 3.32730 to 2.95239, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 349ms/step - accuracy: 0.8934 - loss: 0.2547 - precision_2: 0.8786 - recall_2: 0.8527 - val_accuracy: 0.5726 - val_loss: 2.9524 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9734 - loss: 0.0830 - precision_2: 0.9730 - recall_2: 0.9599
# Epoch 3: val_loss improved from 2.95239 to 2.27858, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 304ms/step - accuracy: 0.9734 - loss: 0.0828 - precision_2: 0.9730 - recall_2: 0.9601 - val_accuracy: 0.6147 - val_loss: 2.2786 - val_precision_2: 1.0000 - val_recall_2: 0.0985 - learning_rate: 0.0010
# Epoch 4/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9885 - loss: 0.0328 - precision_2: 0.9860 - recall_2: 0.9850
# Epoch 4: val_loss improved from 2.27858 to 1.68215, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 387ms/step - accuracy: 0.9886 - loss: 0.0326 - precision_2: 0.9861 - recall_2: 0.9851 - val_accuracy: 0.6716 - val_loss: 1.6821 - val_precision_2: 1.0000 - val_recall_2: 0.2315 - learning_rate: 0.0010
# Epoch 5/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9889 - loss: 0.0351 - precision_2: 0.9892 - recall_2: 0.9825
# Epoch 5: val_loss improved from 1.68215 to 0.19132, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 365ms/step - accuracy: 0.9888 - loss: 0.0352 - precision_2: 0.9891 - recall_2: 0.9823 - val_accuracy: 0.9179 - val_loss: 0.1913 - val_precision_2: 0.9713 - val_recall_2: 0.8325 - learning_rate: 0.0010
# Epoch 6/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9805 - loss: 0.0547 - precision_2: 0.9739 - recall_2: 0.9766
# Epoch 6: val_loss did not improve from 0.19132
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 354ms/step - accuracy: 0.9806 - loss: 0.0546 - precision_2: 0.9740 - recall_2: 0.9768 - val_accuracy: 0.7263 - val_loss: 1.6300 - val_precision_2: 1.0000 - val_recall_2: 0.3596 - learning_rate: 0.0010
# Epoch 7/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9783 - loss: 0.0529 - precision_2: 0.9736 - recall_2: 0.9709
# Epoch 7: val_loss did not improve from 0.19132
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 336ms/step - accuracy: 0.9783 - loss: 0.0529 - precision_2: 0.9736 - recall_2: 0.9710 - val_accuracy: 0.5916 - val_loss: 2.6965 - val_precision_2: 0.5113 - val_recall_2: 1.0000 - learning_rate: 0.0010
# Epoch 8/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9851 - loss: 0.0399 - precision_2: 0.9743 - recall_2: 0.9878
# Epoch 8: val_loss did not improve from 0.19132
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 329ms/step - accuracy: 0.9852 - loss: 0.0399 - precision_2: 0.9745 - recall_2: 0.9877 - val_accuracy: 0.8947 - val_loss: 0.3718 - val_precision_2: 0.8024 - val_recall_2: 1.0000 - learning_rate: 0.0010
# Epoch 9/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9949 - loss: 0.0220 - precision_2: 0.9941 - recall_2: 0.9936
# Epoch 9: val_loss improved from 0.19132 to 0.09087, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.9950 - loss: 0.0217 - precision_2: 0.9941 - recall_2: 0.9937 - val_accuracy: 0.9684 - val_loss: 0.0909 - val_precision_2: 0.9608 - val_recall_2: 0.9655 - learning_rate: 5.0000e-04
# Epoch 10/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9997 - loss: 0.0031 - precision_2: 0.9993 - recall_2: 1.0000
# Epoch 10: val_loss improved from 0.09087 to 0.03699, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 346ms/step - accuracy: 0.9997 - loss: 0.0031 - precision_2: 0.9993 - recall_2: 1.0000 - val_accuracy: 0.9853 - val_loss: 0.0370 - val_precision_2: 0.9804 - val_recall_2: 0.9852 - learning_rate: 5.0000e-04
# Epoch 11/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 1.0000 - loss: 0.0016 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 11: val_loss improved from 0.03699 to 0.02598, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 351ms/step - accuracy: 1.0000 - loss: 0.0015 - precision_2: 1.0000 - recall_2: 1.0000 - val_accuracy: 0.9853 - val_loss: 0.0260 - val_precision_2: 0.9804 - val_recall_2: 0.9852 - learning_rate: 5.0000e-04
# Epoch 12/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 1.0000 - loss: 7.5090e-04 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 12: val_loss improved from 0.02598 to 0.01860, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 1.0000 - loss: 7.4946e-04 - precision_2: 1.0000 - recall_2: 1.0000 - val_accuracy: 0.9895 - val_loss: 0.0186 - val_precision_2: 0.9853 - val_recall_2: 0.9901 - learning_rate: 5.0000e-04
# Epoch 13/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 1.0000 - loss: 5.2934e-04 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 13: val_loss improved from 0.01860 to 0.01684, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 387ms/step - accuracy: 1.0000 - loss: 5.2661e-04 - precision_2: 1.0000 - recall_2: 1.0000 - val_accuracy: 0.9937 - val_loss: 0.0168 - val_precision_2: 0.9950 - val_recall_2: 0.9901 - learning_rate: 5.0000e-04
# Epoch 14/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 1.0000 - loss: 2.1587e-04 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 14: val_loss improved from 0.01684 to 0.01567, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 414ms/step - accuracy: 1.0000 - loss: 2.2067e-04 - precision_2: 1.0000 - recall_2: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.0157 - val_precision_2: 1.0000 - val_recall_2: 0.9901 - learning_rate: 5.0000e-04
# Epoch 15/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 1.0000 - loss: 2.0664e-04 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 15: val_loss improved from 0.01567 to 0.01517, saving model to MobileNet.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 1.0000 - loss: 2.0756e-04 - precision_2: 1.0000 - recall_2: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.0152 - val_precision_2: 1.0000 - val_recall_2: 0.9901 - learning_rate: 5.0000e-04

# %%
best_MobileNet = tf.keras.models.load_model('MobileNet.keras')
best_MobileNet.evaluate(test_data,verbose=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.9690 - loss: 0.1593 - precision_2: 0.6197 - recall_2: 0.7968
# [0.15379267930984497,
#  0.9679999947547913,
#  0.9919999837875366,
#  0.9465649127960205]

# %%
y_pred = best_MobileNet.predict(test_data)
y_pred = np.round(y_pred)
print(classification_report(y_true,y_pred))
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ad0bb490e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ad0bb490e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 690ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97       125
#            1       0.95      0.99      0.97       125
#
#     accuracy                           0.97       250
#    macro avg       0.97      0.97      0.97       250
# weighted avg       0.97      0.97      0.97       250

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Xception

# %%
base_model = tf.keras.applications.xception.Xception(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SHAPE,
)

for layer in base_model.layers[420:]:
  layer.trainable = True

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

Xception_model = tf.keras.Model(inputs=base_model.input, outputs=x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
optimizer = Adam(learning_rate=0.001)

Xception_model.compile(
    optimizer=optimizer,
    loss=LOSS,
    metrics=['accuracy',Recall(),Precision()]
)

# %%
call_backs = callbacks('xception')
Xception_model.fit(train_data,epochs=15,validation_data=validation_data,callbacks=call_backs)
# Out:
# Epoch 1/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6643 - loss: 0.5965 - precision_3: 0.5898 - recall_3: 0.4488
# Epoch 1: val_loss improved from inf to 0.89747, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 184s 4s/step - accuracy: 0.6669 - loss: 0.5938 - precision_3: 0.5935 - recall_3: 0.4536 - val_accuracy: 0.7137 - val_loss: 0.8975 - val_precision_3: 0.7965 - val_recall_3: 0.4433 - learning_rate: 0.0010
# Epoch 2/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 889ms/step - accuracy: 0.8916 - loss: 0.2383 - precision_3: 0.8619 - recall_3: 0.8562
# Epoch 2: val_loss improved from 0.89747 to 0.81050, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.8927 - loss: 0.2362 - precision_3: 0.8633 - recall_3: 0.8577 - val_accuracy: 0.8421 - val_loss: 0.8105 - val_precision_3: 0.8556 - val_recall_3: 0.7586 - learning_rate: 0.0010
# Epoch 3/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 898ms/step - accuracy: 0.9663 - loss: 0.0896 - precision_3: 0.9567 - recall_3: 0.9567
# Epoch 3: val_loss did not improve from 0.81050
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9661 - loss: 0.0900 - precision_3: 0.9567 - recall_3: 0.9563 - val_accuracy: 0.6695 - val_loss: 2.2816 - val_precision_3: 0.9423 - val_recall_3: 0.2414 - learning_rate: 0.0010
# Epoch 4/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.9831 - loss: 0.0594 - precision_3: 0.9784 - recall_3: 0.9793
# Epoch 4: val_loss improved from 0.81050 to 0.78493, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9830 - loss: 0.0596 - precision_3: 0.9784 - recall_3: 0.9790 - val_accuracy: 0.7516 - val_loss: 0.7849 - val_precision_3: 0.8244 - val_recall_3: 0.5320 - learning_rate: 0.0010
# Epoch 5/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.9659 - loss: 0.0924 - precision_3: 0.9522 - recall_3: 0.9632
# Epoch 5: val_loss did not improve from 0.78493
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 67s 970ms/step - accuracy: 0.9662 - loss: 0.0917 - precision_3: 0.9527 - recall_3: 0.9634 - val_accuracy: 0.7453 - val_loss: 1.1427 - val_precision_3: 1.0000 - val_recall_3: 0.4039 - learning_rate: 0.0010
# Epoch 6/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.9922 - loss: 0.0226 - precision_3: 0.9872 - recall_3: 0.9931
# Epoch 6: val_loss did not improve from 0.78493
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9921 - loss: 0.0228 - precision_3: 0.9870 - recall_3: 0.9930 - val_accuracy: 0.7453 - val_loss: 2.2193 - val_precision_3: 0.9881 - val_recall_3: 0.4089 - learning_rate: 0.0010
# Epoch 7/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 899ms/step - accuracy: 0.9808 - loss: 0.0602 - precision_3: 0.9780 - recall_3: 0.9718
# Epoch 7: val_loss improved from 0.78493 to 0.14647, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9808 - loss: 0.0602 - precision_3: 0.9780 - recall_3: 0.9719 - val_accuracy: 0.9432 - val_loss: 0.1465 - val_precision_3: 0.9681 - val_recall_3: 0.8966 - learning_rate: 0.0010
# Epoch 8/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 889ms/step - accuracy: 0.9907 - loss: 0.0235 - precision_3: 0.9853 - recall_3: 0.9908
# Epoch 8: val_loss improved from 0.14647 to 0.04610, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9908 - loss: 0.0233 - precision_3: 0.9855 - recall_3: 0.9909 - val_accuracy: 0.9811 - val_loss: 0.0461 - val_precision_3: 0.9619 - val_recall_3: 0.9951 - learning_rate: 0.0010
# Epoch 9/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - accuracy: 0.9993 - loss: 0.0070 - precision_3: 0.9989 - recall_3: 0.9993
# Epoch 9: val_loss did not improve from 0.04610
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 66s 978ms/step - accuracy: 0.9992 - loss: 0.0071 - precision_3: 0.9988 - recall_3: 0.9992 - val_accuracy: 0.9684 - val_loss: 0.1377 - val_precision_3: 0.9434 - val_recall_3: 0.9852 - learning_rate: 0.0010
# Epoch 10/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.9973 - loss: 0.0095 - precision_3: 0.9966 - recall_3: 0.9968
# Epoch 10: val_loss did not improve from 0.04610
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9973 - loss: 0.0095 - precision_3: 0.9966 - recall_3: 0.9968 - val_accuracy: 0.9537 - val_loss: 0.1781 - val_precision_3: 1.0000 - val_recall_3: 0.8916 - learning_rate: 0.0010
# Epoch 11/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 898ms/step - accuracy: 0.9991 - loss: 0.0037 - precision_3: 0.9994 - recall_3: 0.9984
# Epoch 11: val_loss did not improve from 0.04610
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 987ms/step - accuracy: 0.9991 - loss: 0.0038 - precision_3: 0.9994 - recall_3: 0.9984 - val_accuracy: 0.7768 - val_loss: 0.9099 - val_precision_3: 1.0000 - val_recall_3: 0.4778 - learning_rate: 0.0010
# Epoch 12/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - accuracy: 0.9987 - loss: 0.0029 - precision_3: 0.9989 - recall_3: 0.9978
# Epoch 12: val_loss did not improve from 0.04610
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 995ms/step - accuracy: 0.9987 - loss: 0.0029 - precision_3: 0.9989 - recall_3: 0.9978 - val_accuracy: 0.9663 - val_loss: 0.1227 - val_precision_3: 1.0000 - val_recall_3: 0.9212 - learning_rate: 5.0000e-04
# Epoch 13/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - accuracy: 1.0000 - loss: 0.0013 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 13: val_loss improved from 0.04610 to 0.03013, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 1.0000 - loss: 0.0013 - precision_3: 1.0000 - recall_3: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.0301 - val_precision_3: 1.0000 - val_recall_3: 0.9901 - learning_rate: 5.0000e-04
# Epoch 14/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 887ms/step - accuracy: 1.0000 - loss: 6.5289e-04 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 14: val_loss did not improve from 0.03013
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 68s 976ms/step - accuracy: 1.0000 - loss: 6.6556e-04 - precision_3: 1.0000 - recall_3: 1.0000 - val_accuracy: 0.9916 - val_loss: 0.0364 - val_precision_3: 1.0000 - val_recall_3: 0.9803 - learning_rate: 5.0000e-04
# Epoch 15/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 929ms/step - accuracy: 1.0000 - loss: 2.3764e-04 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 15: val_loss improved from 0.03013 to 0.02196, saving model to xception.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 1.0000 - loss: 2.4272e-04 - precision_3: 1.0000 - recall_3: 1.0000 - val_accuracy: 0.9979 - val_loss: 0.0220 - val_precision_3: 1.0000 - val_recall_3: 0.9951 - learning_rate: 5.0000e-04

# %%
best_Xception = tf.keras.models.load_model('xception.keras')
best_Xception.evaluate(test_data,verbose=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 0.9774 - loss: 0.0797 - precision_3: 0.6456 - recall_3: 0.7968
# [0.0969008207321167, 0.9760000109672546, 0.9919999837875366, 0.961240291595459]

# %%
y_pred = best_Xception.predict(test_data)
y_pred = np.round(y_pred)
print(classification_report(y_true,y_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 944ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       125
#            1       0.96      0.99      0.98       125
#
#     accuracy                           0.98       250
#    macro avg       0.98      0.98      0.98       250
# weighted avg       0.98      0.98      0.98       250

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
